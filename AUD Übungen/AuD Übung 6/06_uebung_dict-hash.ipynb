# %% [markdown]
# ### Aufgabe 1

# %% [markdown]
# Designe eine Hash-Funktion für eine Hash-Tabelle der Größe $m$ mittels $\sin$-Funktion. Was sind Vor- und Nachteile gegenüber Modulo?
#
# $f(x)$ = $(sin(x)^2 \cdot (m - \epsilon))$

# %% [markdown]
# ### Aufgabe 2

# %% [markdown]
# Gib eine Formel für die Wahrscheinlichkeit an, dass bei $n$ zufällig gewählten Schlüsseln aus einer Hashtabelle der Größe $m$ mindestens zwei den gleichen Hash-Wert erzeugen. Was sind die Implikationen für das Design von Hash-Tabellen?
#
# $\bar p(n,m) = \frac{m!}{m-n! \cdot m^n}$
#
# $p(n,m) = 1- \bar p(n,m)$

# %%
from math import factorial
#birthday paradox (Wie hoch ist die wahrscheinlichkeit das von n menschen am gleichen tag geburtstag haben)
m = 365
n = 30

p = 1-(factorial(m)/(factorial(m-n)* m**n))
print(p)
# Out:
# 0.7063162427192686

# %% [markdown]
# ### Aufgabe 3: Implementieren einer Hash-Tabelle

# %% [markdown]
# Implementiere eine Hash-Tabelle mittels Listen und selbsterstellter Funktionen. Sie soll auf Chaining als Kollisionsbehandlung basieren. Fülle dazu die untenstehenden Funktionen aus und orientiere dich an der vollständig definierten removeEntry-Funktion. Nutze bei der Berechnung des Hashwertes die Funktion stringAsInteger, um String in Integer umzuwandeln. Nach Fertigstellung der Funktionen sollte die untenstehende beispielhafte Nutzung der Hash-Tabelle die folgende oder eine äquivalente Ausgabe haben:
# > [[], [], []]
# > [[['Donut', 0.59]], [], []]
# > [[['Donut', 0.59]], [], [['Carrots', 1.49]]]
# > [[['Donut', 0.59]], [], [['Carrots', 1.49], ['Chips', 1.49]]]
# > [[['Donut', 0.59]], [], [['Carrots', 1.49], ['Chips', 2.49]]]
# > [[['Donut', 0.59]], [], [['Chips', 2.49]]]
# > ['Chips', 1.2]
# > [[['Donut', 0.59]], [], [['Chips', 2.49]]]

# %%
def stringAsInteger(string):
    binaryString = ''.join(format(ord(character), '08b') for character in string) # Convert each character to its 8-bit binary representation and join them
    integer = int(binaryString, 2) # Convert the binary string to a large integer
    return integer

# %%
def find(dic, key):
    #Hashvalue
    hashValue = stringAsInteger(key) % len(dic)
    
    #Liste finden
    hashList = dic[hashValue]
    
    #Wer in der Liste finden
    for i in range(len(hashList)):
        entry = hashList[i]
        if nkey == key:
            return hashValue, i
    return hashValue, None
    
def addEntry(dic, key, value):
    hashValue, index = find(dic, key)
    if index == None:
        dic[hashValue] += [(key, value)]
    else:
        dic[hashValue] += [(key, value)]

def getEntry (dic, key):
    hashValue, index = find(dic, key)
    if index == None:
        return "Not Saved"
        
    else:
        return dic[hashValue][index]
    
def removeEntry(dic, key):
    hashValue, index = find(dic, key)
    if (index != None):
        dic[hashValue].pop(index)

# %%
dicSize = 3
dic = [[] for t in range(dicSize)] 
print(dic)
addEntry(dic,'Donut', 0.59)
print(dic)
addEntry(dic,'Carrots', 1.49)
print(dic)
addEntry(dic,'Chips', 1.49)
print(dic)
addEntry(dic,'Chips', 2.49)
print(dic)
removeEntry(dic,'Carrots')
print(dic)
entry = getEntry(dic,'Chips')
entry[1] = 1.2
print(entry)
print(dic)
# Out:
# [[], [], []]
# [[('Donut', 0.59)], [], []]
# [[('Donut', 0.59)], [], [('Carrots', 1.49)]]
# [[('Donut', 0.59)], [], [('Carrots', 1.49), ('Chips', 1.49)]]
# [[('Donut', 0.59)], [], [('Carrots', 1.49), ('Chips', 1.49), ('Chips', 2.49)]]
# [[('Donut', 0.59)], [], [('Chips', 1.49), ('Chips', 2.49)]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 15
#      13 print(dic)
#      14 entry = getEntry(dic,'Chips')
# ---> 15 entry[1] = 1.2
#      16 print(entry)
#      17 print(dic)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### Aufgabe 4: Implementieren von Sets

# %% [markdown]
# **a)** Designe und implementiere eine Hash-Tabelle für eine Menge von Schlüsseln (Integer, die größer-gleich 0 sind) ohne Werte, die möglichst eine geringe Zeitkomplexität für Lesen, Hinzufügen und Löschen sowie möglichst wenig Kollisionen hat und speichereffizient ist. Nutze dazu nur Listen und selbst definierte Funktionen. Nutze nicht Chaining.
# Als Orientierung nutze die unten aufgeführten Funktionsköpfe.

# %% [markdown]
# *Hinweis: Es gibt unterschiedliche Stellen, die variabel sind: die Größe (size), die Hash-Funktion, die Struktur der Tabelle, die Kollisionsbehandlung und die Details der Kollisionsbehandlung.
# Solltest du keine Idee haben, wie man herangehen könnte, nutze lineares Sondieren und den unten aufgeführten Code.*

# %% [markdown]
# *Die Idee ist, dass leere Einträge mit -2 gekennzeichnet sind und gelöschte mit -1.*

# %%
def findInSet(dic, key):
    hashValue = key%len(dic)
    
    i = 0
    while dic((hashValue+i)%len(dic) )!= key and i <= len(dic) and dic((hashValue+i) %len(dic))>= -1  :
        i += 1
    if i == len(dic):
        hashValue, None
    else:
        hashValue, i
    
    
    
def addToSet(dic, key):
   

def isInSet(dic, key):
    index = findInSet(dic, key)
    return dic[index] >= 0
    
def removeFromSet(dic, key):
    index = findInSet(dic, key)
    if dic[index] >= 0:
        dic[index] =- 1

def countCollisions(dic, key):
    hashValue, index = find(dic, key)
    if index >0:
        return 1
    else:
        return 0

# %% [markdown]
# **b)** Miss die Kollisionen und Speichereffizienz mit dem folgenden Code

# %%
keyList = [674, 7336, 546, 4469, 1844, 9261, 9960, 225, 198, 814, 495, 6147, 4386, 5438, 5538, 1346, 3113, 100, 9371, 9159, 8414, 3902, 1391, 1898, 9030, 3776, 76, 1264, 1204, 1744, 3220, 5836, 9399, 7707, 223, 8846, 2726, 9126, 1822, 7481, 369, 789, 27, 4404, 1066, 9139, 345, 2587, 9337, 73, 1330, 7365, 7117, 1838, 104, 1256, 1341, 1301, 655, 1331, 1284, 4374, 8220, 9738, 800, 3604, 11, 2143, 4443, 1, 1981, 6543, 6365, 6046, 1698, 2627, 2357, 3318, 129, 3147, 9881, 1891, 1924, 4957, 5551, 4616, 5112, 1374, 6636, 3957, 2260, 3492, 43, 5279, 5846, 6922, 271, 4778, 3258, 186, 2140, 591, 2711, 35, 2392, 7639, 389, 3798, 6960, 1376, 356, 547, 7389, 221, 5885, 8836, 4790, 25, 404, 46, 1616, 722, 206, 664, 1799, 3873, 1490, 273, 10, 296, 5111, 338, 8043, 4100, 1400, 20, 29, 2609, 2714, 2701, 2074, 9327, 4416, 928, 187, 45, 940, 6410, 2133, 148, 1461, 7, 7191, 3868, 4907, 1975, 2157, 59, 1949, 2526, 3293, 1736, 4373, 1579, 387, 162, 879, 2852, 358, 1983, 6154, 582, 4399, 906, 7347, 723, 285, 241, 370, 123, 5, 105, 4649, 72, 3150, 4169, 60, 5947, 5228, 2177, 632, 6008, 4044, 1885, 935, 65, 7957, 7155, 559, 5084, 4805, 2269, 9955, 1802, 6176, 9279, 8858, 2968, 7825, 6478, 875, 7244, 4777, 7561, 9357, 2491, 6660, 1618, 94, 140, 185, 214, 968, 312, 2618, 1405, 448, 3116, 4869, 1270, 1138, 1363, 3043, 6647, 181, 2248, 3881, 3384, 26, 5695, 3526, 3911, 677, 3582, 9289, 5791, 964, 1731, 6421, 426, 7359, 2573, 51, 1165, 8061, 388, 1809, 5068, 1876, 86, 9982, 5672, 5205, 18, 143, 1971, 2819, 4201, 7778, 9766, 9160, 921, 8, 349, 5645, 1158, 6426, 961, 2650, 5789, 3966, 1173, 6409, 2928, 155, 394, 433, 174, 3042, 3906, 4730, 8349, 2800, 2700, 6194, 5342, 4539, 6830, 5746, 4892, 2633, 303, 3023, 1232, 62, 9039, 85, 2196, 2581, 8940, 2717, 5819, 3606, 2537, 87, 34, 948, 1561, 1723, 1928, 323, 1858, 3511, 3383, 5220, 8900, 822, 597, 1654, 982, 5981, 7492, 4054, 5193, 2315, 462, 7442, 239, 954, 13, 2651, 1198, 9216, 114, 1954, 4, 1633, 326, 1056, 132, 1307, 3813, 743, 4319, 816, 3499, 2753, 7675, 1225, 803, 199, 6519, 2230, 7568, 2146, 90, 8096, 6695, 120, 8244, 469, 1847, 2042, 1773, 8810, 999, 739, 7841, 3874, 3096, 315, 560, 4200, 705, 332, 1433, 5654, 673, 1661, 2107, 6650, 1372, 836, 9617, 352, 8980, 5208, 9059, 8861, 4166, 1147, 215, 222, 7898, 2008, 53, 1868, 830, 408, 1436, 6669, 5734, 282, 3311, 5209, 2025, 918, 131, 135, 503, 1745, 309, 37, 975, 9681, 167, 5479, 2536, 4134, 504, 49, 1634, 4523, 3227, 1697, 1632, 3999, 479, 6156, 2755, 7057, 8227, 4103, 28, 2907, 6, 317, 2263, 963, 5609, 4172, 7460, 3263, 77, 1401, 52, 806, 399, 42, 245, 3673, 2733, 2336, 1193, 240, 116, 450, 7236, 324, 107, 8659, 6819, 3381, 985, 8440, 1453, 5832, 9760, 3732, 208, 308, 9031, 6752, 483, 5408, 9792, 7335, 5210, 1114, 12, 457, 599, 1783, 6943, 3930, 8644, 165, 9627, 6768, 250, 8883, 490, 2228, 729, 3014, 1388, 622, 3037, 1923, 5565, 16, 2312, 3714, 713, 472, 1493, 678, 179, 1497, 3762, 266, 2, 365, 437, 7843, 83, 2351, 7372, 5330, 6999, 126, 127, 2191, 9332, 5031, 47, 1955, 1831, 2225, 2628, 2213, 6532, 868, 420, 1282, 382, 128, 84, 232, 30, 6739, 6472, 4534, 7496, 3154, 2317, 2521, 4009, 7448, 1659, 536, 3, 67, 3579, 874, 517, 1014, 200, 480, 4962, 124, 1673, 3375, 1092, 8551, 3219, 99, 54, 1365, 4557, 9717, 414, 212, 669, 812, 9, 965, 2773, 21, 2543, 2576, 40, 763, 799, 670, 91, 5028, 482, 4482, 70, 115, 7539, 1778, 5562, 4668, 178, 112, 1033, 44, 1865, 4400, 1629, 2154, 8672, 4484, 78, 3921, 9751, 5895, 1529, 1889, 9203, 8682, 8214, 1460, 41, 256, 63, 1295, 3158, 1851, 6628, 3030, 656, 8489, 4561, 386, 8092, 2463, 2424, 8141, 103, 5265, 6296, 558, 2167, 1162, 413, 8817, 4427, 3884, 1544, 118, 244, 9129, 2434, 8175, 5683, 8280, 837, 1084, 1437, 61, 108, 1699, 706, 1655, 306, 4418, 4642, 2978, 136, 2998, 80, 2227, 3755, 1641, 952, 1484, 1361, 234, 1392, 119, 0, 6773, 8746, 8959, 3987, 263, 5005, 152, 3581, 5080, 1979, 2579, 8932, 6132, 626, 337, 2926, 305, 288, 1161, 571, 807, 3495, 4797, 22, 4980, 193, 210, 1567, 563, 2947, 2915, 254, 17, 1086, 31, 6806, 790, 5420, 6171, 1703, 3107, 1082, 14, 205, 9603, 6274, 141, 9109, 2215, 15, 580, 5174, 2096, 1315, 66, 111, 93, 2045, 242, 6692, 849, 945, 3595, 1937, 650, 1276, 7472, 2829, 9701, 3078, 1554, 68, 2589, 902, 1328, 2091, 251, 841, 1709, 6649, 189, 7322, 631, 278, 6607, 7748, 7279, 7545, 5129, 8517, 1546, 96, 113, 7723, 55, 9866, 3252, 2933, 846, 2822, 3213, 859, 2608, 1648, 7317, 154, 936, 4177, 1622, 3370, 1766, 436, 248]
size = 1000
menge = [-2] * size
for key in keyList:
    addToSet(menge, key)

collisions = 0
maxCollisions = 0
for key in keyList:
    count = countCollisions(menge, key)
    collisions += count
    if count > maxCollisions:
        maxCollisions = count

print("Durchschnitt der Kollisionen pro Eintrag", collisions / len(keyList))
print("Maximale Anzahl an Kollisionen pro Eintrag", maxCollisions)
print("Füllgrad der Hash-Tabelle", len(keyList) / size)

# %% [markdown]
# **c)** Welche Möglichkeiten gibt es die gemessenen Werte zu verbessern?
